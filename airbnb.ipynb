# %%
import pandas as pd
import requests
import warnings
warnings.filterwarnings('ignore')
import pymongo

# %%
f = "airbnb-listings.csv"
f_df = pd.read_csv(f, delimiter=';', encoding = 'latin-1')
f_df.head()
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0   2501888   https://www.airbnb.com/rooms/2501888  20170306202425
# 1    377609    https://www.airbnb.com/rooms/377609  20170306202425
# 2  15643010  https://www.airbnb.com/rooms/15643010  20170306202425
# 3   2236988   https://www.airbnb.com/rooms/2236988  20170306202425
# 4  14788276  https://www.airbnb.com/rooms/14788276  20170306202425
#
#   Last Scraped                                               Name  \
# 0   2017-03-07                                Private bed in home
# 1   2017-03-07                     Lake House minutes to Downtown
# 2   2017-03-07          Modern New Apartment Close to Everything!
# 3   2017-03-07                          Austin Waterfront Retreat
# 4   2017-03-07  Stay at the Domain's hotest residencial property.
#
#                                              Summary  \
# 0  Sofa bed in the media room on the first floor....
# 1                                                NaN
# 2  Close to the Barton Creek Greenbelt, S Lamar, ...
# 3  Magnificent Austin waterfront home on Barton C...
# 4  Find indulgence the moment you enter the bouti...
#
#                                                Space  \
# 0  Modernist home with a strong influence from MC...
# 1  Located just 7 minutes to Downtown, and 4 minu...
# 2                                                NaN
# 3  Retreat within the city of Austin.  12 minutes...
# 4                                                NaN
#
#                                          Description Experiences Offered  \
# 0  Sofa bed in the media room on the first floor....                none
# 1  Located just 7 minutes to Downtown, and 4 minu...                none
# 2  Close to the Barton Creek Greenbelt, S Lamar, ...                none
# 3  Magnificent Austin waterfront home on Barton C...                none
# 4  Find indulgence the moment you enter the bouti...                none
#
#                                Neighborhood Overview  \
# 0  Upscale area of West Lake Hills on a bluff ove...
# 1                                                NaN
# 2                                                NaN
# 3  Quiet neighborhood tucked away in Austin.  Min...
# 4                                                NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#   Review Scores Communication Review Scores Location Review Scores Value  \
# 0                        10.0                    9.0                 9.0
# 1                        10.0                   10.0                 9.0
# 2                        10.0                   10.0                10.0
# 3                        10.0                   10.0                10.0
# 4                        10.0                   10.0                 9.0
#
#   License Jurisdiction Names Cancellation Policy  \
# 0     NaN                NaN            flexible
# 1     NaN                NaN              strict
# 2     NaN                NaN            moderate
# 3     NaN                NaN              strict
# 4     NaN                NaN            moderate
#
#   Calculated host listings count Reviews per Month  \
# 0                              1              2.42
# 1                              1              0.54
# 2                              1              1.86
# 3                              1              0.21
# 4                              1              0.69
#
#                      Geolocation  \
# 0  30.2863434604, -97.8104775775
# 1  30.3028051776, -97.7942255855
# 2  30.2521539737, -97.7995481364
# 3   30.2752712576, -97.843114474
# 4  30.4001335924, -97.7241364202
#
#                                             Features
# 0  Host Has Profile Pic,Host Identity Verified,Is...
# 1  Host Has Profile Pic,Host Identity Verified,Is...
# 2  Host Has Profile Pic,Host Identity Verified,Is...
# 3             Host Has Profile Pic,Is Location Exact
# 4             Host Has Profile Pic,Is Location Exact
#
# [5 rows x 89 columns]

# %%
f_df.columns
# Out:
# Index(['ID', 'Listing Url', 'Scrape ID', 'Last Scraped', 'Name', 'Summary',
#        'Space', 'Description', 'Experiences Offered', 'Neighborhood Overview',
#        'Notes', 'Transit', 'Access', 'Interaction', 'House Rules',
#        'Thumbnail Url', 'Medium Url', 'Picture Url', 'XL Picture Url',
#        'Host ID', 'Host URL', 'Host Name', 'Host Since', 'Host Location',
#        'Host About', 'Host Response Time', 'Host Response Rate',
#        'Host Acceptance Rate', 'Host Thumbnail Url', 'Host Picture Url',
#        'Host Neighbourhood', 'Host Listings Count',
#        'Host Total Listings Count', 'Host Verifications', 'Street',
#        'Neighbourhood', 'Neighbourhood Cleansed',
#        'Neighbourhood Group Cleansed', 'City', 'State', 'Zipcode', 'Market',
#        'Smart Location', 'Country Code', 'Country', 'Latitude', 'Longitude',
#        'Property Type', 'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
#        'Beds', 'Bed Type', 'Amenities', 'Square Feet', 'Price', 'Weekly Price',
#        'Monthly Price', 'Security Deposit', 'Cleaning Fee', 'Guests Included',
#        'Extra People', 'Minimum Nights', 'Maximum Nights', 'Calendar Updated',
#        'Has Availability', 'Availability 30', 'Availability 60',
#        'Availability 90', 'Availability 365', 'Calendar last Scraped',
#        'Number of Reviews', 'First Review', 'Last Review',
#        'Review Scores Rating', 'Review Scores Accuracy',
#        'Review Scores Cleanliness', 'Review Scores Checkin',
#        'Review Scores Communication', 'Review Scores Location',
#        'Review Scores Value', 'License', 'Jurisdiction Names',
#        'Cancellation Policy', 'Calculated host listings count',
#        'Reviews per Month', 'Geolocation', 'Features'],
#       dtype='object')

# %%
n_df = f_df[[
    'Name','Street',
    'City', 'State', 'Zipcode','Property Type', 
    'Review Scores Rating']].copy()
n_df.head()
# Out:
#                                                 Name  \
# 0                                Private bed in home
# 1                     Lake House minutes to Downtown
# 2          Modern New Apartment Close to Everything!
# 3                          Austin Waterfront Retreat
# 4  Stay at the Domain's hotest residencial property.
#
#                                               Street             City State  \
# 0  Buckeye Trail, West Lake Hills, TX 78746, Unit...  West Lake Hills    TX
# 1       Westlake Dr, Austin, TX 78746, United States           Austin    TX
# 2  South MoPac Expressway, Austin, TX 78746, Unit...           Austin    TX
# 3  Bend O River Drive, Austin, TX 78746, United S...           Austin    TX
# 4  Esperanza Crossing, Austin, TX 78758, United S...           Austin    TX
#
#   Zipcode Property Type  Review Scores Rating
# 0   78746         Other                  94.0
# 1   78746         House                  96.0
# 2   78746     Apartment                  97.0
# 3   78746         House                  96.0
# 4   78758   Condominium                  93.0

# %%
n_df.rename(columns={'Zipcode':'Zip',
                     'Property Type':'Type',
                     'Number of Reviews':'Review Count',
                     'Street':'Address',
                     'Review Scores Rating':'Average Rating'}, 
                 inplace=True)

# %%
d = n_df.dropna()

# %%
d['State'] = d['State'].str.upper()

# %%
d.State.unique()
# Out:
# array(['TX', 'MA', 'CO', 'IL', 'NY', 'CA', 'LA', 'TN', 'OR', 'WA', 'MP',
#        'DC', 'MD'], dtype=object)

# %%
d = d.set_index('Name')

# %%
d['Ratings2'] = d['Average Rating'] * (5/100)

# %%
d = d.drop(['Average Rating'],axis=1)
d.rename(columns={'Ratings2':'Average Rating'}, 
                 inplace=True)
d.head()
# Out:
#                                                                                              Address  \
# Name
# Private bed in home                                Buckeye Trail, West Lake Hills, TX 78746, Unit...
# Lake House minutes to Downtown                          Westlake Dr, Austin, TX 78746, United States
# Modern New Apartment Close to Everything!          South MoPac Expressway, Austin, TX 78746, Unit...
# Austin Waterfront Retreat                          Bend O River Drive, Austin, TX 78746, United S...
# Stay at the Domain's hotest residencial property.  Esperanza Crossing, Austin, TX 78758, United S...
#
#                                                               City State  \
# Name
# Private bed in home                                West Lake Hills    TX
# Lake House minutes to Downtown                              Austin    TX
# Modern New Apartment Close to Everything!                   Austin    TX
# Austin Waterfront Retreat                                   Austin    TX
# Stay at the Domain's hotest residencial property.           Austin    TX
#
#                                                      Zip         Type  \
# Name
# Private bed in home                                78746        Other
# Lake House minutes to Downtown                     78746        House
# Modern New Apartment Close to Everything!          78746    Apartment
# Austin Waterfront Retreat                          78746        House
# Stay at the Domain's hotest residencial property.  78758  Condominium
#
#                                                    Average Rating
# Name
# Private bed in home                                          4.70
# Lake House minutes to Downtown                               4.80
# Modern New Apartment Close to Everything!                    4.85
# Austin Waterfront Retreat                                    4.80
# Stay at the Domain's hotest residencial property.            4.65

# %%
#open the connection to mongodb and call the database
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.vacation

# %%
for row in d.iterrows():
    db.accommodations.insert_one(
        {
            "Listing Name":row[0],
            "Address":row[1]['Address'],
            "City":row[1]['City'],
            "State":row[1]['State'],
            "Zip":row[1]['Zip'],
            "Average Rating":row[1]['Average Rating'],
            "Type":row[1]['Type']
        }
    )

# %%
aaa = db.Users.distinct("Friends", { "user_id": 1623 })

# %%
myresults = list(db.accommodations.find())

# %%
myresults[1]['Listing Name']
# Out:
# 'Lake House minutes to Downtown'

# %%
for i in myresults:
    papa = myresults[0]

# %%
myresults
# Out:
# [{'_id': ObjectId('5ce18a1532edb16258678718'),
#   'Listing Name': 'Private bed in home',
#   'Address': 'Buckeye Trail, West Lake Hills, TX 78746, United States',
#   'City': 'West Lake Hills',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 4.7,
#   'Type': 'Other'},
#  {'_id': ObjectId('5ce18a1532edb16258678719'),
#   'Listing Name': 'Lake House minutes to Downtown',
#   'Address': 'Westlake Dr, Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb1625867871a'),
#   'Listing Name': 'Modern New Apartment Close to Everything!',
#   'Address': 'South MoPac Expressway, Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867871b'),
#   'Listing Name': 'Austin Waterfront Retreat',
#   'Address': 'Bend O River Drive, Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb1625867871c'),
#   'Listing Name': "Stay at the Domain's hotest residencial property.",
#   'Address': 'Esperanza Crossing, Austin, TX 78758, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78758.0,
#   'Average Rating': 4.65,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1532edb1625867871d'),
#   'Listing Name': 'Studio Apt Close to Zilker/Barton Springs/360',
#   'Address': 'Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 4.95,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867871e'),
#   'Listing Name': 'Comfort & Convenience in Backyard Studio w/Kitchen',
#   'Address': 'Munson Street, Austin, TX 78721, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78721.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Guesthouse'},
#  {'_id': ObjectId('5ce18a1532edb1625867871f'),
#   'Listing Name': 'Private Room in The Austin Oasis House Lake Travis',
#   'Address': 'Sutton Drive, Austin, TX 78734, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78734.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678720'),
#   'Listing Name': 'Eclectic Austin Cottage',
#   'Address': 'Stewart Road, Austin, TX 78734, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78734.0,
#   'Average Rating': 4.6000000000000005,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678721'),
#   'Listing Name': 'Delightful Hill Country Casetta',
#   'Address': 'Running Deer Trail, Austin, TX 78734, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78734.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678722'),
#   'Listing Name': 'Hip Retro Remodeled 2BR Retreat',
#   'Address': 'Broadview Street, Austin, TX 78723, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78723.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678723'),
#   'Listing Name': 'Special! Jetsons MODsquad +Sauna!',
#   'Address': 'Pershing Drive, Austin, TX 78723, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78723.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678724'),
#   'Listing Name': 'Central Austin 3-story Mansion - Treehouse feel',
#   'Address': 'Westbrook Drive, Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 4.6000000000000005,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678725'),
#   'Listing Name': 'Retro Room w/ Firm Queen Futon',
#   'Address': 'Basswood Lane, Austin, TX 78723, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78723.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678726'),
#   'Listing Name': 'great 3br home near heart of Austin',
#   'Address': 'Ruiz Street, Austin, TX 78723, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78723.0,
#   'Average Rating': 4.95,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678727'),
#   'Listing Name': 'Modern, Landscaped Central Retreat',
#   'Address': 'Norwood Road, Austin, TX 78722, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78722.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678728'),
#   'Listing Name': 'Cultural District Flat at UT',
#   'Address': 'Pearl Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 5.0,
#   'Type': 'Bed & Breakfast'},
#  {'_id': ObjectId('5ce18a1532edb16258678729'),
#   'Listing Name': 'Perfect SXSW Spot. Centrally Located, Spacious 2/2',
#   'Address': 'Rio Grande Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 4.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867872a'),
#   'Listing Name': 'Westlake house with Sparkling Pool',
#   'Address': 'Cuesta Verde, Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 4.75,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb1625867872b'),
#   'Listing Name': 'Private Room Zilker/Downtown',
#   'Address': 'Inwood Circle, Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb1625867872c'),
#   'Listing Name': "Bright & Cozy Room in 1950's East Austin Charmer",
#   'Address': 'Blueberry Trail, Austin, TX 78723, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78723.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb1625867872d'),
#   'Listing Name': 'SXSW Home with Pool/Hot Tub - Sleeps 9',
#   'Address': 'Regents Park, Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb1625867872e'),
#   'Listing Name': '1/1 Apartment. Stay during SXSW.',
#   'Address': 'Barton Skyway, Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867872f'),
#   'Listing Name': 'Cozy Greenbelt Hideaway',
#   'Address': 'Barton Skyway, Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 4.65,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678730'),
#   'Listing Name': 'Perfect SXSW Apt Zilker/Downtown',
#   'Address': 'Bartons Bluff Lane, Austin, TX 78746, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678731'),
#   'Listing Name': 'Large Private Room w/Private Bath',
#   'Address': 'Swiftcurrent Trail, West Lake Hills, TX 78746, United States',
#   'City': 'West Lake Hills',
#   'State': 'TX',
#   'Zip': 78746.0,
#   'Average Rating': 5.0,
#   'Type': 'Bed & Breakfast'},
#  {'_id': ObjectId('5ce18a1532edb16258678732'),
#   'Listing Name': 'Memory foam bed -  Keyless Entry',
#   'Address': 'Gloucester Lane, Austin, TX 78723, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78723.0,
#   'Average Rating': 4.95,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678733'),
#   'Listing Name': 'Extra Room in New House',
#   'Address': 'Samuel Huston Avenue, Austin, TX 78721, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78721.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678734'),
#   'Listing Name': 'Barton - 1 bed 1 bath close to downtown & zilker',
#   'Address': 'Barton View Drive, Austin, TX 78735, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78735.0,
#   'Average Rating': 4.65,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678735'),
#   'Listing Name': 'East Austin Home',
#   'Address': 'Broadhill Drive, Austin, TX 78723, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78723.0,
#   'Average Rating': 4.75,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678736'),
#   'Listing Name': 'Private Efficiency, Pool/Tennis',
#   'Address': 'Anderson Mill Road, Austin, TX 78750, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78750.0,
#   'Average Rating': 4.5,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678737'),
#   'Listing Name': 'Hip Downtown Condo with Loft',
#   'Address': 'East 4th Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 3.85,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678738'),
#   'Listing Name': 'Downtown Austin Groovy 2/2 Condo',
#   'Address': 'East 4th Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 4.65,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678739'),
#   'Listing Name': 'Spacious Loft overlooking 6th St C8',
#   'Address': 'East 6th Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 4.95,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867873a'),
#   'Listing Name': 'EXCLUSIVE 2 BR IN AUSTIN! FULL AMENITIES! 3TB2ACAC',
#   'Address': 'Red River Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 3.6500000000000004,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1532edb1625867873b'),
#   'Listing Name': '2BR Renovated Downtown Condo',
#   'Address': 'East 4th Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 4.5,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867873c'),
#   'Listing Name': 'Spacious one-bedroom on UT campus',
#   'Address': 'Nueces Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 4.9,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867873d'),
#   'Listing Name': 'Lakeway Treehouse',
#   'Address': 'Wee Scot Cove, Lakeway, TX 78734, United States',
#   'City': 'Lakeway',
#   'State': 'TX',
#   'Zip': 78734.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb1625867873e'),
#   'Listing Name': 'Perfect Location in â\x9d¤ï¸\x8f of Downtown ATX!',
#   'Address': 'East 4th Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 4.9,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1532edb1625867873f'),
#   'Listing Name': 'Lake Austin Guesthouse - Pool & Spa',
#   'Address': 'River Road, Austin, TX 78734, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78734.0,
#   'Average Rating': 4.5,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678740'),
#   'Listing Name': '5BR/5BA Lake Double Decker BoatHous',
#   'Address': 'Big Horn Drive, Austin, TX 78734, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78734.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678741'),
#   'Listing Name': 'City Loft w 3 Balconies on 6th - C1',
#   'Address': 'East 6th Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 4.55,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678742'),
#   'Listing Name': 'Cool Condo in the Heart of Downtown! SXSW Ready',
#   'Address': 'Brazos Street, Austin, TX 78701, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78701.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1532edb16258678743'),
#   'Listing Name': 'Seawind Garden Homes - 415 Seawind Street',
#   'Address': 'Seawind Street, Lakeway, TX 78734, United States',
#   'City': 'Lakeway',
#   'State': 'TX',
#   'Zip': 78734.0,
#   'Average Rating': 4.3500000000000005,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb16258678744'),
#   'Listing Name': 'Treetop Room in Sunny Pondside Home',
#   'Address': 'Beaufort Road, Boston, MA 02130, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2130.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678745'),
#   'Listing Name': "Stay in Boston's best neighborhood!",
#   'Address': 'Green Street, Boston, MA 02130, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2130.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678746'),
#   'Listing Name': 'Great location, large room, and private bath.',
#   'Address': 'Greenough Park, Boston, MA 02130, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2130.0,
#   'Average Rating': 4.6000000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678747'),
#   'Listing Name': "Cozy 1 Bd Artist's Sanctuary",
#   'Address': 'South Huntington Avenue, Boston, MA 02130, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2130.0,
#   'Average Rating': 5.0,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1532edb16258678748'),
#   'Listing Name': 'Welcome to cozy groundfloor 2rm apt',
#   'Address': 'Sheridan Street, Boston, MA 02130, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2130.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678749'),
#   'Listing Name': 'Parkside Apartment- Cozy and Roomy!',
#   'Address': 'Wachusett Street, Boston, MA 02130, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2130.0,
#   'Average Rating': 4.45,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867874a'),
#   'Listing Name': 'Quiet and comfy in Jamaica Plain',
#   'Address': 'Buckley Avenue, Boston, MA 02130, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2130.0,
#   'Average Rating': 4.65,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867874b'),
#   'Listing Name': 'Peaceful/Fun area, 4 minute walk to "T"',
#   'Address': 'Montebello Road, Boston, MA 02130, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2130.0,
#   'Average Rating': 4.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867874c'),
#   'Listing Name': '*Cosy place near Airport/Downtown and the Beach*',
#   'Address': 'Brandywyne Drive, Boston, MA 02128, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2128.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867874d'),
#   'Listing Name': 'Cosy bedroom near Airport/Downtown and the Beach.',
#   'Address': 'Brandywyne Drive, Boston, MA 02128, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2128.0,
#   'Average Rating': 4.5,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867874e'),
#   'Listing Name': 'Temple Street By Maverick, Three',
#   'Address': 'Temple Street, Boston, MA 02114, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2114.0,
#   'Average Rating': 4.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867874f'),
#   'Listing Name': 'BOSTON - MGH -Beacon Hill- Downtown- great locatio',
#   'Address': 'Blossom Street, Boston, MA 02114, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2114.0,
#   'Average Rating': 4.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678750'),
#   'Listing Name': '1 BR Brownstone Freedom Trail',
#   'Address': 'Main Street, Boston, MA 02129, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2129.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678751'),
#   'Listing Name': 'Amazing Harbor View w/Private Deck',
#   'Address': 'Webster Street, Boston, MA 02128, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2128.0,
#   'Average Rating': 3.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678752'),
#   'Listing Name': 'E2 Steps from Maverick Sq',
#   'Address': 'Maverick Street, Boston, MA 02128, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2128.0,
#   'Average Rating': 4.6000000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678753'),
#   'Listing Name': '1 br / 1 ba in the heart of Charlestown',
#   'Address': 'Seminary Street, Boston, MA 02129, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2129.0,
#   'Average Rating': 4.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678754'),
#   'Listing Name': 'Central Boston Beacon Hill 2brm',
#   'Address': 'Anderson Street, Boston, MA 02114, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2114.0,
#   'Average Rating': 4.9,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678755'),
#   'Listing Name': 'Beautiful 1 Bedroom in Beacon Hill',
#   'Address': 'Phillips st, Boston, MA 02114, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2114.0,
#   'Average Rating': 4.4,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678756'),
#   'Listing Name': "Historic servant's quarters",
#   'Address': 'Temple Street, Boston, MA 02114, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2114.0,
#   'Average Rating': 4.45,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678757'),
#   'Listing Name': 'Beacon Hill Studio across from Public Gardens',
#   'Address': 'Beacon Street, Boston, MA 02108, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2108.0,
#   'Average Rating': 4.55,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678758'),
#   'Listing Name': 'Studio apartment in heart of boston',
#   'Address': 'Winter St, Boston, MA 02111, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2111.0,
#   'Average Rating': 4.05,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678759'),
#   'Listing Name': 'Marriott Custom House',
#   'Address': 'McKinley Square, Boston, MA 02109, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2109.0,
#   'Average Rating': 5.0,
#   'Type': 'Other'},
#  {'_id': ObjectId('5ce18a1532edb1625867875a'),
#   'Listing Name': 'Beacon Hill  1BR Amazing Views',
#   'Address': 'Mount Vernon Street, Boston, MA 02108, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2108.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867875b'),
#   'Listing Name': 'DOWNTOWN MODERN 2 BED',
#   'Address': 'Essex Street, Boston, MA 02111, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2111.0,
#   'Average Rating': 3.85,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867875c'),
#   'Listing Name': 'Pondside Spacious Condo',
#   'Address': 'Pershing Road, Boston, MA 02130, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2130.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867875d'),
#   'Listing Name': "Urban oasis trendy JP 'hood - suite",
#   'Address': 'Greenough Avenue, Boston, MA 02130, United States',
#   'City': 'Boston',
#   'State': 'MA',
#   'Zip': 2130.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb1625867875e'),
#   'Listing Name': '1 bedroom loft  (Convention Center)',
#   'Address': '17th Street, Denver, CO 80202, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80202.0,
#   'Average Rating': 4.7,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867875f'),
#   'Listing Name': 'Relaxing Loft with Sauna & Yoga',
#   'Address': '17th Street, Denver, CO 80202, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80202.0,
#   'Average Rating': 4.95,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678760'),
#   'Listing Name': 'Downtown Condo - ALL 5 Star Reviews',
#   'Address': '15th St, Denver, CO 80202, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80202.0,
#   'Average Rating': 4.9,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678761'),
#   'Listing Name': 'Luxury Penthouse Suite in LODO',
#   'Address': 'Arapahoe Street, Denver, CO 80202, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80202.0,
#   'Average Rating': 4.95,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678762'),
#   'Listing Name': 'Urban Oasis',
#   'Address': 'Emerson Street, Denver, CO 80218, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80218.0,
#   'Average Rating': 5.0,
#   'Type': 'Loft'},
#  {'_id': ObjectId('5ce18a1532edb16258678763'),
#   'Listing Name': 'Entire Luxury Apt Minutes from LODO',
#   'Address': 'Acoma Street, Denver, CO 80204, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80204.0,
#   'Average Rating': 4.5,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678764'),
#   'Listing Name': 'Charming studio, Capitol view!',
#   'Address': 'Sherman Street, Denver, CO 80203, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80203.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678765'),
#   'Listing Name': 'Jazzy, Cozy and Cheap!  City Park',
#   'Address': 'York Street, Denver, CO 80206, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80206.0,
#   'Average Rating': 4.25,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678766'),
#   'Listing Name': 'SkyView Loft, in Healing Center',
#   'Address': 'York Street, Denver, CO 80206, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80206.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678767'),
#   'Listing Name': 'TENNYSON-2Basecamp Queen Airbed-420',
#   'Address': 'Tennyson Street, Denver, CO 80212, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80212.0,
#   'Average Rating': 5.0,
#   'Type': 'Bungalow'},
#  {'_id': ObjectId('5ce18a1532edb16258678768'),
#   'Listing Name': 'Uptown Dreamland!',
#   'Address': 'Franklin Street, Denver, CO 80218, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80218.0,
#   'Average Rating': 4.95,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb16258678769'),
#   'Listing Name': 'Colorful Denver Apt Filled w/ Love',
#   'Address': 'East Arizona Avenue, Denver, CO 80224, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80224.0,
#   'Average Rating': 4.5,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867876a'),
#   'Listing Name': 'Hideaway in the Highlands!',
#   'Address': 'Julian Street, Denver, CO 80211, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80211.0,
#   'Average Rating': 4.75,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1532edb1625867876b'),
#   'Listing Name': 'Millennium Park Paradise for 10 [Lake]',
#   'Address': 'Loop, Chicago, IL 60602, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60602.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867876c'),
#   'Listing Name': 'PRESTIGE MICHIGAN AVE APT',
#   'Address': 'Loop, Chicago, IL 60601, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60601.0,
#   'Average Rating': 4.65,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1532edb1625867876d'),
#   'Listing Name': 'Windy City Luxury in LOOP w/ Balcony Downtown!',
#   'Address': 'Loop, Chicago, IL 60601, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60601.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867876e'),
#   'Listing Name': 'Windy City Lux- A Gem in the Clouds',
#   'Address': 'Loop, Chicago, IL 60601, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60601.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867876f'),
#   'Listing Name': "BUSINESS OASIS 5*AMENITIES 24/7 GYM + Mariano's",
#   'Address': 'Loop, Chicago, IL 60601, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60601.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678770'),
#   'Listing Name': 'Private Bedroom in the heart of Gold Coast',
#   'Address': 'Gold Coast, Chicago, IL 60610, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60610.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678771'),
#   'Listing Name': 'MOST LUXURY BUILDING DOWNTOWN Pool',
#   'Address': 'Chicago, IL 60601, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60601.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678772'),
#   'Listing Name': 'Skyline View',
#   'Address': 'Bronzeville, Chicago, IL 60653, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60653.0,
#   'Average Rating': 4.2,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb16258678773'),
#   'Listing Name': 'Private 2 Bedroom 1 Bath w/ Kitchen',
#   'Address': 'Edgewater, Chicago, IL 60660, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60660.0,
#   'Average Rating': 4.7,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678774'),
#   'Listing Name': 'Quiet, Sunny Room by Lake & UofC',
#   'Address': 'Kenwood, Chicago, IL 60653, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60653.0,
#   'Average Rating': 4.9,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1632edb16258678775'),
#   'Listing Name': 'Urban farm in the city, 1 block from L!',
#   'Address': 'Washington Park, Chicago, IL 60637, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60637.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb16258678776'),
#   'Listing Name': 'Fun & Funky Musician Condo (Entire Home)',
#   'Address': 'Irving Park, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 5.0,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1632edb16258678777'),
#   'Listing Name': 'near downtown and mccormick place',
#   'Address': 'Chicago, IL 60653, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60653.0,
#   'Average Rating': 4.3500000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678778'),
#   'Listing Name': 'Charming Home by McCormick Place #1',
#   'Address': 'Oakland, Chicago, IL 60653, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60653.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Townhouse'},
#  {'_id': ObjectId('5ce18a1632edb16258678779'),
#   'Listing Name': 'Bedroom with bath and large family room.',
#   'Address': 'Belmont Cragin, Chicago, IL 60639, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60639.0,
#   'Average Rating': 5.0,
#   'Type': 'Bungalow'},
#  {'_id': ObjectId('5ce18a1632edb1625867877a'),
#   'Listing Name': 'Historic Irving Park 9BR Three Flat - Sleeps 24!',
#   'Address': 'Avondale, Chicago, IL 60641, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60641.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb1625867877b'),
#   'Listing Name': 'Comfy Sofa Bed, Wide View of City',
#   'Address': 'Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 5.0,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1632edb1625867877c'),
#   'Listing Name': 'Cozy room #1',
#   'Address': 'Avondale, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.6000000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867877d'),
#   'Listing Name': 'Comfortable room near Logan Square.',
#   'Address': 'Avondale, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867877e'),
#   'Listing Name': 'Cozy Room in Avondale 2',
#   'Address': 'Avondale, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867877f'),
#   'Listing Name': 'Peaceful, Easy to Cubs & Wrigley Field',
#   'Address': 'Avondale, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.4,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678780'),
#   'Listing Name': 'Beauty on a Budget Logan Square w/ Breakfast',
#   'Address': 'Avondale, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.7,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678781'),
#   'Listing Name': 'Private bedroom in condo',
#   'Address': 'South Shore, Chicago, IL 60649, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60649.0,
#   'Average Rating': 5.0,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1632edb16258678782'),
#   'Listing Name': 'Sleep 10 at The Bean! (5i)',
#   'Address': 'Loop, Chicago, IL 60602, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60602.0,
#   'Average Rating': 4.6000000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678783'),
#   'Listing Name': 'Millennium Park Private bd/bth',
#   'Address': 'Loop, Chicago, IL 60602, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60602.0,
#   'Average Rating': 4.5,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678784'),
#   'Listing Name': '350 PER MON., PER PERSON -BUNK BED, FREE WIFI, &.',
#   'Address': 'South Chicago, Chicago, IL 60617, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60617.0,
#   'Average Rating': 3.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678785'),
#   'Listing Name': 'LAKESHORE EAST 1 BED MILLENNIUM PARK LOCATION +SPA',
#   'Address': 'Loop, Chicago, IL 60601, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60601.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678786'),
#   'Listing Name': 'Detached 1Bdrm w/ Living Room!',
#   'Address': 'Chicago, IL 60617, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60617.0,
#   'Average Rating': 4.4,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678787'),
#   'Listing Name': 'Cozy East Chicago home',
#   'Address': 'South Shore, Chicago, IL 60649, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60649.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb16258678788'),
#   'Listing Name': 'Sunny Art-Filled Chicago 2BD Avondale/Logan Square',
#   'Address': 'Avondale, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.95,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678789'),
#   'Listing Name': 'Hinterlands  (Lic.#2288893)',
#   'Address': 'Avondale, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867878a'),
#   'Listing Name': 'Urban Oasis @ Fulton House!',
#   'Address': 'Garfield Park, Chicago, IL 60612, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60612.0,
#   'Average Rating': 4.5,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867878b'),
#   'Listing Name': 'Quiet Guest Room with comfy bed',
#   'Address': 'Garfield Park, Chicago, IL 60612, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60612.0,
#   'Average Rating': 4.75,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb1625867878c'),
#   'Listing Name': 'The Secret Garden - at Humboldt Park',
#   'Address': 'Humboldt Park, Chicago, IL 60651, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60651.0,
#   'Average Rating': 4.2,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867878d'),
#   'Listing Name': 'Logan Square - full size bed',
#   'Address': 'Avondale, Chicago, IL 60641, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60641.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb1625867878e'),
#   'Listing Name': 'Cozy Room Minutes From Train!',
#   'Address': 'Little Village, Chicago, IL 60623, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60623.0,
#   'Average Rating': 4.7,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867878f'),
#   'Listing Name': 'Vintage Chicago Flat',
#   'Address': 'Chicago, IL 60651, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60651.0,
#   'Average Rating': 3.35,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678790'),
#   'Listing Name': "IDA'S 2720 (2F)",
#   'Address': 'Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 4.45,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678791'),
#   'Listing Name': 'Spacious Room/Floor near McCormick and downtown',
#   'Address': 'Armour Square, Chicago, IL 60616, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60616.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678792'),
#   'Listing Name': 'Warm & Modern Pilsen Home - 1 Bedroom (Queen)',
#   'Address': 'Pilsen, Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678793'),
#   'Listing Name': 'Sunny bedroom in Pilsen',
#   'Address': 'Pilsen, Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678794'),
#   'Listing Name': 'Heart of Chicago Garden Studio',
#   'Address': 'Pilsen, Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678795'),
#   'Listing Name': 'Near The Loop and McCormick Place',
#   'Address': 'Chinatown, Chicago, IL 60616, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60616.0,
#   'Average Rating': 4.65,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678796'),
#   'Listing Name': 'Cozzy Chicago hut',
#   'Address': 'Pilsen, Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 4.55,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678797'),
#   'Listing Name': 'Spacious cozy Duplex by Downtown',
#   'Address': 'Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 3.5,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1632edb16258678798'),
#   'Listing Name': 'Private room in Pilsen',
#   'Address': 'Pilsen, Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb16258678799'),
#   'Listing Name': 'Beautiful comfy apartment in Pilsen',
#   'Address': 'Pilsen, Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 4.15,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867879a'),
#   'Listing Name': 'ARTpartment Retreat | Bright & Bold in Bridgeport',
#   'Address': 'Bridgeport, Chicago, IL 60616, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60616.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867879b'),
#   'Listing Name': 'Beautiful Belmont Apartment',
#   'Address': 'Roscoe Village, Chicago, IL 60657, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60657.0,
#   'Average Rating': 4.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867879c'),
#   'Listing Name': 'Cozy 2br 4bd apt',
#   'Address': 'Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867879d'),
#   'Listing Name': 'The Sox Flat',
#   'Address': 'Bridgeport, Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb1625867879e'),
#   'Listing Name': 'Cozy and Well Located Ravenswood Home Chicago',
#   'Address': 'North Center, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb1625867879f'),
#   'Listing Name': 'Wrigleyville',
#   'Address': 'North Center, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb162586787a0'),
#   'Listing Name': 'Cozy home near Denver!',
#   'Address': 'West Burlington Place, Denver, CO 80221, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80221.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787a1'),
#   'Listing Name': 'Cozy Bungalow Down Town Denver Room',
#   'Address': 'Wyandot Street, Denver, CO 80221, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80221.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787a2'),
#   'Listing Name': 'Beautiful Uptown Historic Home',
#   'Address': 'Washington Street, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787a3'),
#   'Listing Name': 'Exclusive Denver Location! ST2',
#   'Address': 'Little Raven Street, Denver, CO 80202, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80202.0,
#   'Average Rating': 4.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb162586787a4'),
#   'Listing Name': 'Entire House for Business Travel',
#   'Address': 'Curtis Street, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 4.9,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787a5'),
#   'Listing Name': 'Modern Townhome/ great neighborhood',
#   'Address': 'East Academy Boulevard, Denver, CO 80230, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80230.0,
#   'Average Rating': 4.45,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787a6'),
#   'Listing Name': 'Cutsey in Curtis Park',
#   'Address': 'Stout Street, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 4.9,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787a7'),
#   'Listing Name': '1BDSteps away from Denver nightlife',
#   'Address': 'Market Street, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 4.45,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb162586787a8'),
#   'Listing Name': 'Large Victorian Downtown Denver 420',
#   'Address': 'Ogden Street, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787a9'),
#   'Listing Name': 'Warm and friendly apartment',
#   'Address': 'Fairmount Drive, Denver, CO 80230, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80230.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb162586787aa'),
#   'Listing Name': 'Cozy room near downtown - Jill',
#   'Address': 'Champa Street, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787ab'),
#   'Listing Name': 'Queen Bed in Modern, Lux Townhome!',
#   'Address': 'Emerson St, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 5.0,
#   'Type': 'Townhouse'},
#  {'_id': ObjectId('5ce18a1632edb162586787ac'),
#   'Listing Name': 'Pvt. Room Lux Townhome w/ Full Bath',
#   'Address': '24th Street, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 4.9,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787ad'),
#   'Listing Name': 'RiNo Studio Fireplace Roofdeck View',
#   'Address': '34th Street, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 4.7,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb162586787ae'),
#   'Listing Name': 'Gorgeous Remodeled Townhome!',
#   'Address': '31st Street, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 4.65,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787af'),
#   'Listing Name': 'Beautiful 3B/2BA 1870s Brick House',
#   'Address': 'Tremont Place, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 4.75,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787b0'),
#   'Listing Name': 'LoDo/BallPark FUN!!',
#   'Address': 'Blake Street, Denver, CO 80205, United States',
#   'City': 'Denver',
#   'State': 'CO',
#   'Zip': 80205.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb162586787b1'),
#   'Listing Name': 'Private room-NO FEES',
#   'Address': 'East 44th Street, Austin, TX 78751, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78751.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787b2'),
#   'Listing Name': 'Peaceful sunlit room in Hyde Park',
#   'Address': 'Avenue H, Austin, TX 78751, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78751.0,
#   'Average Rating': 4.95,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787b3'),
#   'Listing Name': 'Beautiful  Private Cottage',
#   'Address': 'E 50th St, Austin, TX 78751, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78751.0,
#   'Average Rating': 4.9,
#   'Type': 'Cabin'},
#  {'_id': ObjectId('5ce18a1632edb162586787b4'),
#   'Listing Name': 'Nice Place',
#   'Address': 'East 51st Street, Austin, TX 78751, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78751.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb162586787b5'),
#   'Listing Name': 'The Studio at Avenue B',
#   'Address': 'Avenue B, Austin, TX 78751, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78751.0,
#   'Average Rating': 4.9,
#   'Type': 'Bungalow'},
#  {'_id': ObjectId('5ce18a1632edb162586787b6'),
#   'Listing Name': 'Peaceful Austin Meditation Bedroom!',
#   'Address': 'Valcour Bay Lane, Austin, TX 78754, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78754.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787b7'),
#   'Listing Name': 'Your Home Away from Home (Near Samsung)',
#   'Address': 'Long Day Drive, Austin, TX 78754, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78754.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787b8'),
#   'Listing Name': 'Small guest house',
#   'Address': 'Wareham Lane, Austin, TX 78739, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78739.0,
#   'Average Rating': 3.5,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787b9'),
#   'Listing Name': 'East Austin Guesthouse with Deck & Yard',
#   'Address': 'Chicon Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Guesthouse'},
#  {'_id': ObjectId('5ce18a1632edb162586787ba'),
#   'Listing Name': 'The Marshall Studio in East Austin',
#   'Address': 'Holly Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 4.9,
#   'Type': 'Guesthouse'},
#  {'_id': ObjectId('5ce18a1632edb162586787bb'),
#   'Listing Name': 'Magazine-Worthy Alva Bungalow',
#   'Address': 'Leona Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 4.65,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787bc'),
#   'Listing Name': 'Pecan Gardens Cottage',
#   'Address': 'Thompson Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 5.0,
#   'Type': 'Guesthouse'},
#  {'_id': ObjectId('5ce18a1632edb162586787bd'),
#   'Listing Name': 'East Austin Home Away from Home',
#   'Address': 'Santa Rosa Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787be'),
#   'Listing Name': 'Modern Bungalow in Hip East Austin!',
#   'Address': 'Willow Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 4.2,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787bf'),
#   'Listing Name': 'Charming Yellow Fort',
#   'Address': 'Anthony Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb162586787c0'),
#   'Listing Name': 'The 2nd Awesomest Place in Austin',
#   'Address': 'Chicon Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787c1'),
#   'Listing Name': 'Urban Loft in Hip East Austin Downtown ACL East 6',
#   'Address': 'East 6th Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 5.0,
#   'Type': 'Loft'},
#  {'_id': ObjectId('5ce18a1632edb162586787c2'),
#   'Listing Name': 'East Side Charmer! Walk to SXSW!',
#   'Address': 'Haskell Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 4.75,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787c3'),
#   'Listing Name': 'Central East Austin House',
#   'Address': 'Gunter St, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 4.95,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787c4'),
#   'Listing Name': 'Luxury Condo, City Skyline, SXSW',
#   'Address': 'Waller Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 4.95,
#   'Type': 'Loft'},
#  {'_id': ObjectId('5ce18a1632edb162586787c5'),
#   'Listing Name': 'Modern Minimalism walk to Downtown!',
#   'Address': 'Angelina Street, Austin, TX 78702, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78702.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787c6'),
#   'Listing Name': 'Private room North Central Austin',
#   'Address': 'Glenn Lane, Austin, TX 78753, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78753.0,
#   'Average Rating': 4.9,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787c7'),
#   'Listing Name': 'Cozy room in West Campus',
#   'Address': 'Rio Grande Street, Austin, TX 78705, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78705.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1632edb162586787c8'),
#   'Listing Name': 'Room in Grad Student Kingdom',
#   'Address': 'King Street, Austin, TX 78705, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78705.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1632edb162586787c9'),
#   'Listing Name': 'spacious, natural light, waterfall!',
#   'Address': 'Pollyanna Avenue, Austin, TX 78753, United States',
#   'City': 'Austin',
#   'State': 'TX',
#   'Zip': 78753.0,
#   'Average Rating': 4.25,
#   'Type': 'Apartment'},
# ...
#   'Address': 'North Center, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1732edb16258678ac6'),
#   'Listing Name': 'Cozy Pilsen Reading Room',
#   'Address': 'Pilsen, Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ac7'),
#   'Listing Name': 'Cozy Garden Unit Located in North Center',
#   'Address': 'North Center, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.55,
#   'Type': 'Guest suite'},
#  {'_id': ObjectId('5ce18a1732edb16258678ac8'),
#   'Listing Name': 'Bright clean artist studio loft!',
#   'Address': 'Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 5.0,
#   'Type': 'Loft'},
#  {'_id': ObjectId('5ce18a1732edb16258678ac9'),
#   'Listing Name': 'Cute Roscoe Village Apartment',
#   'Address': 'Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.6000000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678aca'),
#   'Listing Name': 'Charming Museum Park Town House',
#   'Address': 'South Loop/Printers Row, Chicago, IL 60605, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60605.0,
#   'Average Rating': 4.95,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1732edb16258678acb'),
#   'Listing Name': 'Luxury 2 bedroom city view apt.',
#   'Address': 'South Loop/Printers Row, Chicago, IL 60616, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60616.0,
#   'Average Rating': 4.9,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678acc'),
#   'Listing Name': 'Beautiful South Loop Surprise',
#   'Address': 'South Loop/Printers Row, Chicago, IL 60605, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60605.0,
#   'Average Rating': 4.3500000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678acd'),
#   'Listing Name': 'Fantastic River North Location (6)',
#   'Address': 'River North, Chicago, IL 60654, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60654.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ace'),
#   'Listing Name': 'Cozy Gold Coast Studio, 2 mins to subway!',
#   'Address': 'Near North Side, Chicago, IL 60610, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60610.0,
#   'Average Rating': 4.3500000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678acf'),
#   'Listing Name': '2BD River North Perfect Location 2 Full Bathrooms',
#   'Address': 'River North, Chicago, IL 60610, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60610.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ad0'),
#   'Listing Name': 'Studio near Downtown',
#   'Address': 'River North, Chicago, IL 60610, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60610.0,
#   'Average Rating': 4.1000000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ad1'),
#   'Listing Name': 'Modern 2 Bed 2 Bath Condo City View',
#   'Address': 'River North, Chicago, IL 60654, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60654.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ad2'),
#   'Listing Name': '2 BD Condo by downtown,park,lake',
#   'Address': 'River North, Chicago, IL 60610, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60610.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1732edb16258678ad3'),
#   'Listing Name': 'Stunning Views! Perfect Location!',
#   'Address': 'Streeterville, Chicago, IL 60611, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60611.0,
#   'Average Rating': 4.65,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ad4'),
#   'Listing Name': 'Spacious Luxury 1 Bedroom in River North',
#   'Address': 'River North, Chicago, IL 60654, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60654.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ad5'),
#   'Listing Name': 'Gold Coast/Michigan Ave/Downtown Large 3 Bedroom',
#   'Address': 'Streeterville, Chicago, IL 60611, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60611.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ad6'),
#   'Listing Name': 'Pretty Gold Coast 1BR',
#   'Address': 'Gold Coast, Chicago, IL 60610, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60610.0,
#   'Average Rating': 5.0,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1732edb16258678ad7'),
#   'Listing Name': 'Gold Coast/River North 2 bedroom vintage condo',
#   'Address': 'River North, Chicago, IL 60610, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60610.0,
#   'Average Rating': 5.0,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1732edb16258678ad8'),
#   'Listing Name': 'Cozy spot conveniently located in downtown',
#   'Address': 'Streeterville, Chicago, IL 60611, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60611.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ad9'),
#   'Listing Name': "Art Collector's Pied-a'-terre",
#   'Address': 'South Shore, Chicago, IL 60649, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60649.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1732edb16258678ada'),
#   'Listing Name': 'Elegant LOOP Downtown w/ GYM, SKYPARK, HOT TUB',
#   'Address': 'Chicago, IL 60601, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60601.0,
#   'Average Rating': 4.45,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678adb'),
#   'Listing Name': 'Awesome Lofted Room in the heart of Downtown!',
#   'Address': 'Loop, Chicago, IL 60602, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60602.0,
#   'Average Rating': 4.45,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678adc'),
#   'Listing Name': 'LAKESHORE MILLENNIUM PARK IV',
#   'Address': 'Loop, Chicago, IL 60601, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60601.0,
#   'Average Rating': 4.95,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678add'),
#   'Listing Name': '2 Bedroom Downtown Loft - Pinterest Worthy',
#   'Address': 'Old Town, Chicago, IL 60610, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60610.0,
#   'Average Rating': 5.0,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1732edb16258678ade'),
#   'Listing Name': 'Stunning lakeside apt next to Millennium Park',
#   'Address': 'Loop, Chicago, IL 60601, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60601.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678adf'),
#   'Listing Name': 'LUX 2 BEDROOMS - CLEAN w/2 BATHS | NEW INDOOR POOL',
#   'Address': 'Loop, Chicago, IL 60601, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60601.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ae0'),
#   'Listing Name': 'Loft Wrigleyville Apt! Private bedroom & bath!',
#   'Address': 'Chicago, IL 60657, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60657.0,
#   'Average Rating': 4.3500000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ae1'),
#   'Listing Name': 'Roscoe House: Wrigleyville Boystown',
#   'Address': 'Lakeview, Chicago, IL 60657, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60657.0,
#   'Average Rating': 5.0,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1732edb16258678ae2'),
#   'Listing Name': '350 PER MONTH, PER PERSON - BUNK BED, FREE WIFI &',
#   'Address': 'South Chicago, Chicago, IL 60617, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60617.0,
#   'Average Rating': 4.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ae3'),
#   'Listing Name': 'Comfortable Studio to Ease and Flow',
#   'Address': 'Boystown, Chicago, IL 60657, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60657.0,
#   'Average Rating': 4.7,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ae4'),
#   'Listing Name': 'Clean, Comfy 1BR-10 Min from Lake and Red Line',
#   'Address': 'Lakeview, Chicago, IL 60613, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60613.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ae5'),
#   'Listing Name': 'Queen Size Bed/Roscoe and Halsted',
#   'Address': 'Lakeview, Chicago, IL 60657, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60657.0,
#   'Average Rating': 4.65,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ae6'),
#   'Listing Name': 'New 2 Bed Condo in Lakeview/Wrigley',
#   'Address': 'Chicago, IL 60613, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60613.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678ae7'),
#   'Listing Name': 'Cubs Fans: Rent entire floor of beautiful Condo',
#   'Address': 'Lakeview, Chicago, IL 60613, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60613.0,
#   'Average Rating': 4.0,
#   'Type': 'Other'},
#  {'_id': ObjectId('5ce18a1732edb16258678ae8'),
#   'Listing Name': 'Space & Privacy - 15 min dwntwn - free parking',
#   'Address': 'Grand Crossing, Chicago, IL 60637, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60637.0,
#   'Average Rating': 4.75,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1732edb16258678ae9'),
#   'Listing Name': 'Clark Street Quarters, a Lincoln Park Oasis!',
#   'Address': 'Lakeview, Chicago, IL 60657, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60657.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678aea'),
#   'Listing Name': 'Lncln-Pk-DePaul-Cubs-Sleep 6- FREE PARKING',
#   'Address': 'Lincoln Park, Chicago, IL 60614, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60614.0,
#   'Average Rating': 4.9,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678aeb'),
#   'Listing Name': 'quiet and convenient to all transit',
#   'Address': 'Lakeview, Chicago, IL 60613, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60613.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Townhouse'},
#  {'_id': ObjectId('5ce18a1732edb16258678aec'),
#   'Listing Name': 'Getaway in East Lakeview/Boystown!',
#   'Address': 'Boystown, Chicago, IL 60657, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60657.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678aed'),
#   'Listing Name': '2 bedroom in beautiful Logan square.',
#   'Address': 'Chicago, IL 60614, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60614.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678aee'),
#   'Listing Name': '2BD Steps away from Wrigley Field',
#   'Address': 'Chicago, IL 60613, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60613.0,
#   'Average Rating': 4.2,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678aef'),
#   'Listing Name': 'Private bed & bath w/garage parking',
#   'Address': 'Irving Park, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.65,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1732edb16258678af0'),
#   'Listing Name': 'Logan Square-Buddy Room - Bed 1',
#   'Address': 'Chicago, IL 60641, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60641.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1732edb16258678af1'),
#   'Listing Name': 'Two Bedroom near train & restaurants',
#   'Address': 'Irving Park, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678af2'),
#   'Listing Name': 'Hyde Park/Kenwood Coach House',
#   'Address': 'Chicago, IL 60615, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60615.0,
#   'Average Rating': 5.0,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1732edb16258678af3'),
#   'Listing Name': 'Beautiful bedroom with private bath',
#   'Address': 'Chicago, IL 60641, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60641.0,
#   'Average Rating': 4.9,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1732edb16258678af4'),
#   'Listing Name': 'Bungalow Suite',
#   'Address': 'Irving Park, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'House'},
#  {'_id': ObjectId('5ce18a1732edb16258678af5'),
#   'Listing Name': 'Private Room a block from blue line',
#   'Address': 'Avondale, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.5,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678af6'),
#   'Listing Name': 'Comfortable bed in Belmont Cragin Area!',
#   'Address': 'Belmont Cragin, Chicago, IL 60634, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60634.0,
#   'Average Rating': 4.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678af7'),
#   'Listing Name': 'Fabulous Flat',
#   'Address': 'Irving Park, Chicago, IL 60641, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60641.0,
#   'Average Rating': 5.0,
#   'Type': 'Condominium'},
#  {'_id': ObjectId('5ce18a1732edb16258678af8'),
#   'Listing Name': 'Huge Logan Square 4-Bed Duplex w/ 2-Car Garage',
#   'Address': 'Avondale, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.8500000000000005,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678af9'),
#   'Listing Name': 'Huge Bright 1 bedroom walk 2 train.',
#   'Address': 'Chicago, IL 60612, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60612.0,
#   'Average Rating': 4.65,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678afa'),
#   'Listing Name': 'Yoga Room On Blue Line Logan Square w/ Breakfast',
#   'Address': 'Avondale, Chicago, IL 60618, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60618.0,
#   'Average Rating': 4.800000000000001,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678afb'),
#   'Listing Name': 'Entire 2BR Apt w/ Parking & 3 Beds',
#   'Address': 'Pilsen, Chicago, IL 60608, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60608.0,
#   'Average Rating': 4.4,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678afc'),
#   'Listing Name': 'The Heart of Chicago, Little Village - "La 26"',
#   'Address': 'Little Village, Chicago, IL 60623, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60623.0,
#   'Average Rating': 4.75,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678afd'),
#   'Listing Name': 'Art filled Apartment Pilsen',
#   'Address': 'Chicago, IL 60623, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60623.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678afe'),
#   'Listing Name': 'Sweet apartment in the heart of Chicago',
#   'Address': 'Little Village, Chicago, IL 60623, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60623.0,
#   'Average Rating': 5.0,
#   'Type': 'Apartment'},
#  {'_id': ObjectId('5ce18a1732edb16258678aff'),
#   'Listing Name': 'Bedroom in Vintage Chicago Flat',
#   'Address': 'Chicago, IL 60651, United States',
#   'City': 'Chicago',
#   'State': 'IL',
#   'Zip': 60651.0,
#   'Average Rating': 3.9000000000000004,
#   'Type': 'Apartment'},
#  ...]

# %%
myresults2 = list(db.accommodations.find('State'))



for x in db.accommodations.find({"State": "TX"}):
  print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-a0c0af109f86> in <module>
# ----> 1 myresults2 = list(db.accommodations.find('State'))
#       2
#       3
#       4
#       5 for x in db.accommodations.find({"State": "TX"}):
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pymongo\collection.py in find(self, *args, **kwargs)
#    1443
#    1444         """
# -> 1445         return Cursor(self, *args, **kwargs)
#    1446
#    1447     def find_raw_batches(self, *args, **kwargs):
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pymongo\cursor.py in __init__(self, collection, filter, projection, skip, limit, no_cursor_timeout, cursor_type, sort, allow_partial_results, oplog_replay, modifiers, batch_size, manipulate, collation, hint, max_scan, max_time_ms, max, min, return_key, show_record_id, snapshot, comment, session)
#     143             spec = {}
#     144
# --> 145         validate_is_mapping("filter", spec)
#     146         if not isinstance(skip, int):
#     147             raise TypeError("skip must be an instance of int")
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pymongo\common.py in validate_is_mapping(option, value)
#     442         raise TypeError("%s must be an instance of dict, bson.son.SON, or "
#     443                         "other type that inherits from "
# --> 444                         "collections.Mapping" % (option,))
#     445
#     446
#
# TypeError: filter must be an instance of dict, bson.son.SON, or other type that inherits from collections.Mapping
